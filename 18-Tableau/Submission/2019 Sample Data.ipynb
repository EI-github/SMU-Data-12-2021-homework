# %%
import pandas as pd

# %%
df = pd.read_csv("data/citibike_2019_sample.csv")
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           574  2019-01-30 17:30:59.7870  2019-01-30 17:40:34.2530
# 1           709  2019-01-23 19:28:12.1530  2019-01-23 19:40:01.7030
# 2          1993  2019-01-26 18:30:29.2160  2019-01-26 19:03:43.0780
# 3           392  2019-01-05 18:31:40.6190  2019-01-05 18:38:13.1980
# 4           543  2019-01-23 15:24:24.9240  2019-01-23 15:33:28.8630
#
#    start station id     start station name  start station latitude  \
# 0             359.0     E 47 St & Park Ave               40.755103
# 1             493.0        W 45 St & 6 Ave               40.756800
# 2             503.0     E 20 St & Park Ave               40.738274
# 3             161.0  LaGuardia Pl & W 3 St               40.729170
# 4            3496.0       1 Ave & E 110 St               40.792327
#
#    start station longitude  end station id     end station name  \
# 0               -73.974987           528.0      2 Ave & E 31 St
# ...

# %%
len(df)
# Out:
# 411032

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411032 entries, 0 to 411031
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             411032 non-null  int64
#  1   starttime                411032 non-null  object
#  2   stoptime                 411032 non-null  object
#  3   start station id         411023 non-null  float64
#  4   start station name       411023 non-null  object
#  5   start station latitude   411032 non-null  float64
#  6   start station longitude  411032 non-null  float64
#  7   end station id           411023 non-null  float64
#  8   end station name         411023 non-null  object
#  9   end station latitude     411032 non-null  float64
#  10  end station longitude    411032 non-null  float64
#  11  bikeid                   411032 non-null  int64
#  12  usertype                 411032 non-null  object
# ...

# %%
df.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 411027           262  2019-12-27 17:28:32.1100  2019-12-27 17:32:54.4220
# 411028           560  2019-12-06 08:56:35.5500  2019-12-06 09:05:56.0270
# 411029           428  2019-12-12 11:35:42.2130  2019-12-12 11:42:50.7930
# 411030           626  2019-12-06 16:18:40.5640  2019-12-06 16:29:07.4200
# 411031           345  2019-12-13 18:46:53.4890  2019-12-13 18:52:38.7030
#
#         start station id                start station name  \
# 411027             432.0                 E 7 St & Avenue A
# 411028            3697.0  W 64 St & Thelonious Monk Circle
# 411029            3306.0                     10 St & 7 Ave
# 411030             533.0                Broadway & W 38 St
# 411031             297.0                   E 15 St & 3 Ave
#
#         start station latitude  start station longitude  end station id  \
# 411027               40.726218               -73.983799          3263.0
# ...
